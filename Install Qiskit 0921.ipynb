# %%
import qiskit
qiskit.__version__
# Out:
# '0.18.2'

# %%
import qiskit, math
import numpy as np
from qiskit import *
from qiskit.visualization import plot_histogram, plot_bloch_vector, plot_bloch_multivector
from math import sqrt, pi

# %%
q = QuantumRegister(2)
c = ClassicalRegister(2)
circuit = QuantumCircuit(q,c)
circuit.draw()
# Out:
#
# q318_0:
#
# q318_1:
#
#  c24: 2/

# %%
#circuit.h(q[0])
circuit.ry(math.pi*0.6082, q[0])
circuit.draw()
# Out:
#         ┌────────────┐
# q318_0: ┤ Ry(1.9107) ├
#         └────────────┘
# q318_1: ──────────────
#
#  c24: 2/══════════════

# %%
simulator = Aer.get_backend('statevector_simulator')
job=execute(circuit, simulator)
result = job.result()

statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.57731621+0.j 0.81652066+0.j 0.        +0.j 0.        +0.j]

# %%
circuit.measure(q, c)
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)

# %% [markdown]
# # 第二題

# %%
q = QuantumRegister(2)
c = ClassicalRegister(2)
circuit = QuantumCircuit(q,c)
circuit.x(q)
circuit.h(q[0])
circuit.cx(q[0], q[1])
circuit.draw()
# Out:
#         ┌───┐┌───┐
# q160_0: ┤ X ├┤ H ├──■──
#         ├───┤└───┘┌─┴─┐
# q160_1: ┤ X ├─────┤ X ├
#         └───┘     └───┘
#  c11: 2/═══════════════

# %%
circuit.measure(q, c)
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'10': 512, '01': 512}

# %%
q = QuantumRegister(2)
c = ClassicalRegister(2)
circuit = QuantumCircuit(q,c)
circuit.h(q[0])
#circuit.ry(math.pi*0.6082, q[0])
circuit.swap(q[0], q[1])
circuit.draw()
# Out:
#         ┌───┐
# q259_0: ┤ H ├─X─
#         └───┘ │
# q259_1: ──────X─
#
#  c16: 2/════════

# %%
simulator = Aer.get_backend('statevector_simulator')
job=execute(circuit, simulator)
result = job.result()

statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.70710678+0.j 0.        +0.j 0.70710678+0.j 0.        +0.j]

# %%
circuit.measure(q, c)
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'00': 525, '10': 499}

# %% [markdown]
# # 第三題

# %%
q1 = QuantumRegister(1)
c1 = ClassicalRegister(1)
circuit1 = QuantumCircuit(q1,c1)
circuit1.x(q1[0])
circuit1.z(q1[0])
circuit1.draw()
# Out:
#         ┌───┐┌───┐
# q515_0: ┤ X ├┤ Z ├
#         └───┘└───┘
#  c33: 1/══════════

# %%
simulator = Aer.get_backend('statevector_simulator')
job=execute(circuit1, simulator)
result = job.result()

statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [ 6.123234e-17+1.49975978e-32j -1.000000e+00-3.67394040e-16j]

# %%
circuit1.h(q1)
circuit1.measure(q1, c1)
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit1, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'1': 1024}

# %%
q2 = QuantumRegister(1)
c2 = ClassicalRegister(1)
circuit2 = QuantumCircuit(q2,c2)
circuit2.h(q2[0])
circuit2.draw()
# Out:
#         ┌───┐
# q411_0: ┤ H ├
#         └───┘
#  c24: 1/═════

# %%
simulator = Aer.get_backend('statevector_simulator')
job=execute(circuit2, simulator)
result = job.result()

statevector = result.get_statevector()
print(statevector)
plot_bloch_multivector(statevector)
# Out:
# [0.70710678+0.j 0.70710678+0.j]

# %%
circuit2.h(q2)
circuit2.measure(q2, c2)
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit2, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'0': 1024}

# %% [markdown]
# # 第四題

# %%
q = QuantumRegister(3)
c = ClassicalRegister(1)
circuit = QuantumCircuit(q,c)
circuit.h(q)
circuit.x(q[0])
circuit.z(q[0])
circuit.y(q[1])
circuit.cswap(q[2], q[0], q[1])
circuit.h(q[2])
circuit.x(q[2])
circuit.draw()
# Out:
#         ┌───┐┌───┐┌───┐
# q523_0: ┤ H ├┤ X ├┤ Z ├─X───────────
#         ├───┤├───┤└───┘ │
# q523_1: ┤ H ├┤ Y ├──────X───────────
#         ├───┤└───┘      │ ┌───┐┌───┐
# q523_2: ┤ H ├───────────■─┤ H ├┤ X ├
#         └───┘             └───┘└───┘
#  c34: 1/════════════════════════════

# %%
circuit.measure(q[2], c)
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'1': 1024}

# %% [markdown]
# # 第五題

# %%
q = QuantumRegister(5)
c = ClassicalRegister(5)
circuit = QuantumCircuit(q,c)
circuit.h(q)
circuit.measure(q, c)
circuit.draw()
# Out:
#         ┌───┐┌─┐
# q563_0: ┤ H ├┤M├────────────
#         ├───┤└╥┘┌─┐
# q563_1: ┤ H ├─╫─┤M├─────────
#         ├───┤ ║ └╥┘┌─┐
# q563_2: ┤ H ├─╫──╫─┤M├──────
#         ├───┤ ║  ║ └╥┘┌─┐
# q563_3: ┤ H ├─╫──╫──╫─┤M├───
#         ├───┤ ║  ║  ║ └╥┘┌─┐
# q563_4: ┤ H ├─╫──╫──╫──╫─┤M├
#         └───┘ ║  ║  ║  ║ └╥┘
#  c36: 5/══════╩══╩══╩══╩══╩═
#               0  1  2  3  4

# %%
simulator = Aer.get_backend('qasm_simulator')
job = execute(circuit, simulator, shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
# Out:
# {'00000': 36, '10101': 41, '01101': 25, '11000': 32, '10000': 33, '00001': 31, '10110': 35, '00010': 29, '11010': 32, '01100': 34, '01010': 24, '10011': 26, '11001': 30, '01000': 38, '11100': 36, '00100': 31, '00101': 33, '10111': 36, '10100': 36, '00111': 36, '11101': 30, '11110': 30, '11011': 31, '01110': 36, '01001': 28, '10001': 28, '10010': 33, '11111': 28, '01011': 25, '01111': 36, '00110': 26, '00011': 39}

# %%
apitoken = '6750360fe839ce09d5d7299f9d1213245f0e3ec9a9cb4f8c9a31c22812ee3e36dcba6c033df55b179869f1ca2ab72e9edec258cd2639393e5162824aab64fa42'
IBMQ.save_account(apitoken)
# Out:
# configrc.store_credentials:WARNING:2021-09-23 19:25:04,859: Credentials already present. Set overwrite=True to overwrite.

# %%
IBMQ.load_account()
provider = IBMQ.get_provider(hub = 'ibm-q', group = 'open', project = 'main')
qcomp = provider.get_backend('ibmq_santiago')
job=execute(circuit, qcomp, shots=1000)
# Out:
# ibmqfactory.load_account:WARNING:2021-09-23 19:30:06,513: Credentials are already in use. The existing account in the session will be replaced.

# %%
from qiskit.tools.monitor import job_monitor
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
result = job.result()
counts = result.get_counts(circuit)

# %%
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)
